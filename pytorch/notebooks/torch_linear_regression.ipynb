# %%
#--train simple linear regression model for crop predictions

# %%
#--import libraries

import torch
import numpy as np

# %%
#--prepare dataset in numpy

inputs=np.array([
    [73, 67, 43],
    [91, 88, 64],
    [87, 134, 58],
    [102, 43, 37],
    [69, 96, 70]
],
dtype="float32"
)

inputs
# Out:
# array([[ 73.,  67.,  43.],
#        [ 91.,  88.,  64.],
#        [ 87., 134.,  58.],
#        [102.,  43.,  37.],
#        [ 69.,  96.,  70.]], dtype=float32)

# %%
targets= np.array([
    [56],
    [81],
    [119],
    [22],
    [103]
],
                 dtype="float32")
targets
# Out:
# array([[ 56.],
#        [ 81.],
#        [119.],
#        [ 22.],
#        [103.]], dtype=float32)

# %%
#--convert into tensors
inputs=torch.from_numpy(inputs)
targets=torch.from_numpy(targets)

print(inputs)
print(targets)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.]])
# tensor([[ 56.],
#         [ 81.],
#         [119.],
#         [ 22.],
#         [103.]])

# %%
#---define random weights and bias
#---x=[5,3]
#---w=[1,3]
#---b=[1,1]
#---y=x * w.T + b

w=torch.randn(1,3,requires_grad=True)
b=torch.randn(1,requires_grad=True)

print(w)
print(b)
# Out:
# tensor([[ 0.2513, -0.1943, -0.1971]], requires_grad=True)
# tensor([-0.3349], requires_grad=True)

# %%
#--define model
def model(x):
  return x @ w.t() + b

# %%
#--generate predictions/forward pass
preds=model(inputs)
print(preds)
# Out:
# tensor([[ -3.4891],
#         [ -7.1866],
#         [-15.9492],
#         [  9.6445],
#         [-15.4517]], grad_fn=<AddBackward0>)

# %%
#---mse loss
def mse(t1,t2):
  diff=t1-t2
  return  torch.sum(diff*diff/diff.numel())

# %%
loss=mse(preds,targets)
print(loss)
#--compute gradients
loss.backward()
#--gradients for weights
print(w)
print(w.grad)
# Out:
# tensor(8742.1162, grad_fn=<SumBackward0>)
# tensor([[ 0.2513, -0.1943, -0.1971]], requires_grad=True)
# tensor([[-13416.6787, -16692.8145,  -9911.1201]])

# %%
#--adjust weights and reset gradients
with torch.no_grad():
  w-=1e-5*w.grad
  b-=1e-5*b.grad
  print(w)
  print(b)
  w.grad.zero_()
  b.grad.zero_()
# Out:
# tensor([[ 0.3854, -0.0274, -0.0980]], requires_grad=True)
# tensor([-0.3332], requires_grad=True)

# %%
#--calculate loss again
preds=model(inputs)
loss=mse(preds,targets)
print(loss)
# Out:
# tensor(4166.1021, grad_fn=<SumBackward0>)

# %%
#---training for multiple epochs
epochs=100
for i in range(epochs):
  preds=model(inputs)
  loss=mse(preds,targets)
  print(" loss :",i,loss)
  loss.backward()

  with torch.no_grad():
    w-=w.grad*1e-5
    b-=b.grad*1e-5
    w.grad.zero_()
    b.grad.zero_()
# Out:
#  loss : 0 tensor(4166.1021, grad_fn=<SumBackward0>)
#  loss : 1 tensor(2267.3193, grad_fn=<SumBackward0>)
#  loss : 2 tensor(1471.6912, grad_fn=<SumBackward0>)
#  loss : 3 tensor(1130.8141, grad_fn=<SumBackward0>)
#  loss : 4 tensor(977.5880, grad_fn=<SumBackward0>)
#  loss : 5 tensor(901.9801, grad_fn=<SumBackward0>)
#  loss : 6 tensor(858.6581, grad_fn=<SumBackward0>)
#  loss : 7 tensor(828.9401, grad_fn=<SumBackward0>)
#  loss : 8 tensor(805.1239, grad_fn=<SumBackward0>)
#  loss : 9 tensor(784.0284, grad_fn=<SumBackward0>)
#  loss : 10 tensor(764.3366, grad_fn=<SumBackward0>)
#  loss : 11 tensor(745.4982, grad_fn=<SumBackward0>)
#  loss : 12 tensor(727.2804, grad_fn=<SumBackward0>)
#  loss : 13 tensor(709.5798, grad_fn=<SumBackward0>)
#  loss : 14 tensor(692.3478, grad_fn=<SumBackward0>)
#  loss : 15 tensor(675.5577, grad_fn=<SumBackward0>)
#  loss : 16 tensor(659.1920, grad_fn=<SumBackward0>)
#  loss : 17 tensor(643.2381, grad_fn=<SumBackward0>)
#  loss : 18 tensor(627.6840, grad_fn=<SumBackward0>)
#  loss : 19 tensor(612.5197, grad_fn=<SumBackward0>)
#  loss : 20 tensor(597.7346, grad_fn=<SumBackward0>)
#  loss : 21 tensor(583.3198, grad_fn=<SumBackward0>)
#  loss : 22 tensor(569.2656, grad_fn=<SumBackward0>)
#  loss : 23 tensor(555.5629, grad_fn=<SumBackward0>)
#  loss : 24 tensor(542.2030, grad_fn=<SumBackward0>)
#  loss : 25 tensor(529.1772, grad_fn=<SumBackward0>)
#  loss : 26 tensor(516.4769, grad_fn=<SumBackward0>)
#  loss : 27 tensor(504.0943, grad_fn=<SumBackward0>)
#  loss : 28 tensor(492.0211, grad_fn=<SumBackward0>)
#  loss : 29 tensor(480.2496, grad_fn=<SumBackward0>)
#  loss : 30 tensor(468.7723, grad_fn=<SumBackward0>)
#  loss : 31 tensor(457.5819, grad_fn=<SumBackward0>)
#  loss : 32 tensor(446.6708, grad_fn=<SumBackward0>)
#  loss : 33 tensor(436.0323, grad_fn=<SumBackward0>)
#  loss : 34 tensor(425.6595, grad_fn=<SumBackward0>)
#  loss : 35 tensor(415.5455, grad_fn=<SumBackward0>)
#  loss : 36 tensor(405.6841, grad_fn=<SumBackward0>)
#  loss : 37 tensor(396.0688, grad_fn=<SumBackward0>)
#  loss : 38 tensor(386.6933, grad_fn=<SumBackward0>)
#  loss : 39 tensor(377.5520, grad_fn=<SumBackward0>)
#  loss : 40 tensor(368.6385, grad_fn=<SumBackward0>)
#  loss : 41 tensor(359.9473, grad_fn=<SumBackward0>)
#  loss : 42 tensor(351.4727, grad_fn=<SumBackward0>)
#  loss : 43 tensor(343.2094, grad_fn=<SumBackward0>)
#  loss : 44 tensor(335.1523, grad_fn=<SumBackward0>)
#  loss : 45 tensor(327.2955, grad_fn=<SumBackward0>)
#  loss : 46 tensor(319.6347, grad_fn=<SumBackward0>)
#  loss : 47 tensor(312.1647, grad_fn=<SumBackward0>)
#  loss : 48 tensor(304.8806, grad_fn=<SumBackward0>)
#  loss : 49 tensor(297.7779, grad_fn=<SumBackward0>)
#  loss : 50 tensor(290.8519, grad_fn=<SumBackward0>)
#  loss : 51 tensor(284.0984, grad_fn=<SumBackward0>)
#  loss : 52 tensor(277.5125, grad_fn=<SumBackward0>)
#  loss : 53 tensor(271.0907, grad_fn=<SumBackward0>)
#  loss : 54 tensor(264.8285, grad_fn=<SumBackward0>)
#  loss : 55 tensor(258.7219, grad_fn=<SumBackward0>)
#  loss : 56 tensor(252.7671, grad_fn=<SumBackward0>)
#  loss : 57 tensor(246.9600, grad_fn=<SumBackward0>)
#  loss : 58 tensor(241.2973, grad_fn=<SumBackward0>)
#  loss : 59 tensor(235.7751, grad_fn=<SumBackward0>)
#  loss : 60 tensor(230.3902, grad_fn=<SumBackward0>)
#  loss : 61 tensor(225.1385, grad_fn=<SumBackward0>)
#  loss : 62 tensor(220.0174, grad_fn=<SumBackward0>)
#  loss : 63 tensor(215.0231, grad_fn=<SumBackward0>)
#  loss : 64 tensor(210.1526, grad_fn=<SumBackward0>)
#  loss : 65 tensor(205.4029, grad_fn=<SumBackward0>)
#  loss : 66 tensor(200.7707, grad_fn=<SumBackward0>)
#  loss : 67 tensor(196.2533, grad_fn=<SumBackward0>)
#  loss : 68 tensor(191.8477, grad_fn=<SumBackward0>)
#  loss : 69 tensor(187.5510, grad_fn=<SumBackward0>)
#  loss : 70 tensor(183.3607, grad_fn=<SumBackward0>)
#  loss : 71 tensor(179.2740, grad_fn=<SumBackward0>)
#  loss : 72 tensor(175.2882, grad_fn=<SumBackward0>)
#  loss : 73 tensor(171.4009, grad_fn=<SumBackward0>)
#  loss : 74 tensor(167.6097, grad_fn=<SumBackward0>)
#  loss : 75 tensor(163.9119, grad_fn=<SumBackward0>)
#  loss : 76 tensor(160.3055, grad_fn=<SumBackward0>)
#  loss : 77 tensor(156.7879, grad_fn=<SumBackward0>)
#  loss : 78 tensor(153.3571, grad_fn=<SumBackward0>)
#  loss : 79 tensor(150.0107, grad_fn=<SumBackward0>)
#  loss : 80 tensor(146.7469, grad_fn=<SumBackward0>)
#  loss : 81 tensor(143.5635, grad_fn=<SumBackward0>)
#  loss : 82 tensor(140.4582, grad_fn=<SumBackward0>)
#  loss : 83 tensor(137.4294, grad_fn=<SumBackward0>)
#  loss : 84 tensor(134.4750, grad_fn=<SumBackward0>)
#  loss : 85 tensor(131.5932, grad_fn=<SumBackward0>)
#  loss : 86 tensor(128.7822, grad_fn=<SumBackward0>)
#  loss : 87 tensor(126.0401, grad_fn=<SumBackward0>)
#  loss : 88 tensor(123.3654, grad_fn=<SumBackward0>)
#  loss : 89 tensor(120.7561, grad_fn=<SumBackward0>)
#  loss : 90 tensor(118.2108, grad_fn=<SumBackward0>)
#  loss : 91 tensor(115.7279, grad_fn=<SumBackward0>)
#  loss : 92 tensor(113.3056, grad_fn=<SumBackward0>)
#  loss : 93 tensor(110.9427, grad_fn=<SumBackward0>)
#  loss : 94 tensor(108.6374, grad_fn=<SumBackward0>)
#  loss : 95 tensor(106.3886, grad_fn=<SumBackward0>)
#  loss : 96 tensor(104.1945, grad_fn=<SumBackward0>)
#  loss : 97 tensor(102.0540, grad_fn=<SumBackward0>)
#  loss : 98 tensor(99.9657, grad_fn=<SumBackward0>)
#  loss : 99 tensor(97.9283, grad_fn=<SumBackward0>)

# %%
#--train a linear regression with torch built-in
import torch.nn as nn

# %%
#--define inputs and targets
inputs=np.array([
    [73, 67, 43],
    [91, 88, 64],
    [87, 134, 58],
    [102, 43, 37],
    [69, 96, 70]
], dtype='float32')

targets=np.array([
    [56, 70],
    [81, 101],
    [119, 133],
    [22, 37],
    [103, 119]
],dtype='float32')

#--convert them into tensors
inputs=torch.from_numpy(inputs)
targets=torch.from_numpy(targets)

print(inputs)
print(targets)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.]])
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %%
#--prepare tensor combined dataset
from torch.utils.data import TensorDataset

train_df=TensorDataset(inputs,targets)
print(train_df)
print(train_df[:2])
# Out:
# <torch.utils.data.dataset.TensorDataset object at 0x7d3d3066e3e0>
# (tensor([[73., 67., 43.],
#         [91., 88., 64.]]), tensor([[ 56.,  70.],
#         [ 81., 101.]]))

# %%
#--split data into batches
from torch.utils.data import DataLoader

batch_size=2
train_dl=DataLoader(train_df,batch_size,shuffle=True)

# %%
#--iterrate through each batch with for loop
for xb,yb in train_dl:
  print(xb)
  print(yb)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 87., 134.,  58.]])
# tensor([[ 56.,  70.],
#         [119., 133.]])
# tensor([[102.,  43.,  37.],
#         [ 91.,  88.,  64.]])
# tensor([[ 22.,  37.],
#         [ 81., 101.]])
# tensor([[69., 96., 70.]])
# tensor([[103., 119.]])

# %%
#--define linear model -> no need to define weights and bias separately
model=nn.Linear(3,2)
print(model.weight)
print(model.bias)
# Out:
# Parameter containing:
# tensor([[ 0.0491,  0.2421,  0.1138],
#         [-0.1090,  0.1609,  0.4811]], requires_grad=True)
# Parameter containing:
# tensor([ 0.5157, -0.3220], requires_grad=True)

# %%
#--no need to add activation function because its a linear regression problem
#--parameters
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0491,  0.2421,  0.1138],
#          [-0.1090,  0.1609,  0.4811]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.5157, -0.3220], requires_grad=True)]

# %%
#--generate predictions
preds=model(inputs)
print(preds)
# Out:
# tensor([[25.2176, 23.1920],
#         [33.5759, 34.7130],
#         [43.8342, 39.6644],
#         [20.1494, 13.2831],
#         [35.1142, 41.2844]], grad_fn=<AddmmBackward0>)

# %%
#--loss function -> use in-built loss function
import torch.nn.functional as F
loss_fn=F.mse_loss
print(loss_fn)
# Out:
# <function mse_loss at 0x7d3df02b2680>

# %%
#--check loss for inputs
loss=loss_fn(preds,targets)
print(loss)
# Out:
# tensor(3535.7090, grad_fn=<MseLossBackward0>)

# %%
#--optimizer -> use in-built optimizer
opt=torch.optim.SGD(model.parameters(),lr=1e-5)
print(opt)
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     lr: 1e-05
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %%
#--train the model
#--pass the inputs to get predictions
#--compute loss
#--compute gradients
#--update the weights
#--reset the gradients

def fit(num_epochs,model,loss_fn,opt,train_dl):
  #--repeat for each epoch
  for epoch in range(num_epochs):

    #--iterations -> pass each batch
    for xb,yb in train_dl:

      #--get the predictions
      preds=model(xb)

      #--compute loss
      loss=loss_fn(preds,yb)

      #--compute gradients
      loss.backward()

      #--update the weights and bias
      opt.step()

      #--reset the gradients to zero
      opt.zero_grad()

    #--print loss for every 10th epoch
    if (epoch+1)%10 ==0:
      print('Epoch [{}/{}] , Loss : {:.4f}'.format(epoch+1,num_epochs,loss))

# %%
#--train the model
fit(100,model,loss_fn,opt,train_dl)
# Out:
# Epoch [10/100] , Loss : 35.1167
# Epoch [20/100] , Loss : 1.7804
# Epoch [30/100] , Loss : 8.1052
# Epoch [40/100] , Loss : 6.5779
# Epoch [50/100] , Loss : 3.5112
# Epoch [60/100] , Loss : 3.1265
# Epoch [70/100] , Loss : 0.8278
# Epoch [80/100] , Loss : 5.8944
# Epoch [90/100] , Loss : 1.3165
# Epoch [100/100] , Loss : 1.8671

# %%
#--generate predictions with trained model
preds=model(inputs)
print(preds)
print(targets)
# Out:
# tensor([[ 57.6294,  70.5086],
#         [ 80.7998, 100.0631],
#         [121.6486, 134.4704],
#         [ 22.7093,  38.0535],
#         [ 98.5878, 117.3797]], grad_fn=<AddmmBackward0>)
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])
